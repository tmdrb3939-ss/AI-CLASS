# %%
import numpy as np

import tensorflow as tf
from tensorflow import keras

import matplotlib.pyplot as plt

# %%
imdb = keras.datasets.imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# %%
len(x_train), len(x_test)
# Out:
# (25000, 25000)

# %%
print(x_train[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
len(x_train[0]), len(x_train[1])
# Out:
# (218, 189)

# %%
y_train[0], y_train[1]
# Out:
# (np.int64(1), np.int64(0))

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([12500, 12500]))

# %%
word_to_index = imdb.get_word_index()


word_to_index = {k:(v+3) for k,v in word_to_index.items()}
word_to_index["<PAD>"] = 0
word_to_index["<START>"] = 1
word_to_index["<UNK>"] = 2
word_to_index["<UNUSED>"] = 3

index_to_word = dict([(value, key) for (key, value) in word_to_index.items()])

# %%
print(''.join([index_to_word[index] for index in x_train[0]]))
# Out:
# <START>thisfilmwasjustbrilliantcastinglocationscenerystorydirectioneveryone'sreallysuitedtheparttheyplayedandyoucouldjustimaginebeingthererobert<UNK>isanamazingactorandnowthesamebeingdirector<UNK>fathercamefromthesamescottishislandasmyselfsoilovedthefacttherewasarealconnectionwiththisfilmthewittyremarksthroughoutthefilmweregreatitwasjustbrilliantsomuchthatiboughtthefilmassoonasitwasreleasedfor<UNK>andwouldrecommendittoeveryonetowatchandtheflyfishingwasamazingreallycriedattheenditwassosadandyouknowwhattheysayifyoucryatafilmitmusthavebeengoodandthisdefinitelywasalso<UNK>tothetwolittleboy'sthatplayedthe<UNK>ofnormanandpaultheywerejustbrilliantchildrenareoftenleftoutofthe<UNK>listithinkbecausethestarsthatplaythemallgrownuparesuchabigprofileforthewholefilmbutthesechildrenareamazingandshouldbepraisedforwhattheyhavedonedon'tyouthinkthewholestorywassolovelybecauseitwastrueandwassomeone'slifeafterallthatwassharedwithusall

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import *

# %%
x_train = pad_sequences(x_train, maxlen=100)
x_test = pad_sequences(x_test, maxlen=100)

# %%
len(x_train[0]),len(x_train[1])
# Out:
# (100, 100)

# %%
print(x_train[0])
# Out:
# [1415   33    6   22   12  215   28   77   52    5   14  407   16   82
#     2    8    4  107  117 5952   15  256    4    2    7 3766    5  723
#    36   71   43  530  476   26  400  317   46    7    4    2 1029   13
#   104   88    4  381   15  297   98   32 2071   56   26  141    6  194
#  7486   18    4  226   22   21  134  476   26  480    5  144   30 5535
#    18   51   36   28  224   92   25  104    4  226   65   16   38 1334
#    88   12   16  283    5   16 4472  113  103   32   15   16 5345   19
#   178   32]

# %%
vocab_size = 10000

model = Sequential()
model.add(Embedding(vocab_size, 64, input_length=100))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from IPython.core import history
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64, epochs=20, verbose=1, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7638 - loss: 0.4635 - val_accuracy: 0.8508 - val_loss: 0.3361
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.9369 - loss: 0.1724 - val_accuracy: 0.8320 - val_loss: 0.4018
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.9934 - loss: 0.0295 - val_accuracy: 0.8292 - val_loss: 0.5275
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9994 - loss: 0.0056 - val_accuracy: 0.8333 - val_loss: 0.6160
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.9995 - loss: 0.0032 - val_accuracy: 0.8355 - val_loss: 0.6552
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 1.0000 - loss: 9.7448e-04 - val_accuracy: 0.8364 - val_loss: 0.6947
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 1.0000 - loss: 5.5615e-04 - val_accuracy: 0.8372 - val_loss: 0.7287
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 0.8143 - val_loss: 0.9189
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 0.8273 - val_loss: 0.8596
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 1.0000 - loss: 5.9096e-04 - val_accuracy: 0.8298 - val_loss: 0.9081
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 1.0000 - loss: 2.4263e-04 - val_accuracy: 0.8302 - val_loss: 0.9520
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 1.0000 - loss: 1.2085e-04 - val_accuracy: 0.8317 - val_loss: 0.9758
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 1.0000 - loss: 8.9272e-05 - val_accuracy: 0.8316 - val_loss: 1.0055
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 1.0000 - loss: 6.9665e-05 - val_accuracy: 0.8326 - val_loss: 1.0282
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 1.0000 - loss: 6.4743e-05 - val_accuracy: 0.8330 - val_loss: 1.0465
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 1.0000 - loss: 3.9522e-05 - val_accuracy: 0.8324 - val_loss: 1.0648
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.9994 - loss: 0.0018 - val_accuracy: 0.8071 - val_loss: 1.2010
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9850 - loss: 0.0447 - val_accuracy: 0.8124 - val_loss: 0.9349
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.9986 - loss: 0.0053 - val_accuracy: 0.8202 - val_loss: 1.0329
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 1.0000 - loss: 6.8811e-04 - val_accuracy: 0.8201 - val_loss: 1.0925

# %%
results = model.evaluate(x_test, y_test, verbose=2)
print(results)
# Out:
# 782/782 - 2s - 3ms/step - accuracy: 0.8201 - loss: 1.0925
# [1.0925434827804565, 0.8200799822807312]

# %%
review = "What can I say about this movie that was already said? It is my favorite time travel sci-fi, adventure epic comedy in the 80's and I love this movie to death! When I saw this movie I was thrown out by its theme. An excellent sci-fi, adventure epic, I LOVE the 80s. It's simple the greatest time travel movie ever happened in the history of world cinema. I love this movie to death, Ilove, love it!"

# %%
import re
review = re.sub("[^0-9a-zA-Z]"," ",review).lower()

# %%
review_encoding = []
for w in review.split():
  index = word_to_index.get(w,2)
  if index <= 10000:
    review_encoding.append(index)
  else:
    review_encoding.append(word_to_index["UNK"])

test_input = pad_sequences([review_encoding], maxlen = 100)
value = model.predict(test_input)
if(value > 0.5):
  print("긍정적인 리뷰입니다.")
else:
  print("부정적인 리뷰입니다.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 긍정적인 리뷰입니다.
